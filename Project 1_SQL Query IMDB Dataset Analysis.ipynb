# %% [markdown]
# ## importing the library

# %%
#numpy -> To perform the mathematical operations
import numpy as np

#Padas -> Data Manipulattion tool
import pandas as pd

#Matplotlib -> Data Visualization tool
import matplotlib.pyplot as plt

#seaborn-> Data Visualization 
import seaborn as sns

#sqlite -> Server-less Database
import sqlite3
# Out:
# C:\Users\asus\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# #Hints
# 1. CONNECT YOUR DATBASE (OR CREATE A CONNECTION )->sqlite3.connect(database)
# 2. use the curser function -> database _variable.curser()
#
# #workflow.
# 1.you need to establish a connection to the database by crating a connewction object
# 2.then ,you have to crate a curser oibject using the curser() method
# 3.then ,excute the query -> curser_object.execute('query')
# 4.to fetch the data ,then use fetchall() method of the curser object

# %%
url = "C:/Users/asus/Downloads/fandango_score_comparison.csv"
df2 = pd.read_csv(url)

# %%
df2
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 0                     86          66              7.1   7.8             5.0
# ...

# %%
url = "C:/Users/asus/Downloads/imdb_top_1000.csv"
df2 = pd.read_csv(url)

# %%
conn = sqlite3.connect('Movies.db')
df2.to_sql('MoviesImdb', con=conn, if_exists='replace', index=False)
# Out:
# 1000

# %% [markdown]
# # 1.Establishing the connection to the data base

# %%
db1="C:/Users/asus/Untitled Folder/Movies.db"
# Connect to SQLite database
connect = sqlite3.connect(db1)
curs=connect.cursor()

# %%
# conn = sqlite3.connect('movies.db')
# df2.to_sql('movies', con=conn, if_exists='replace', index=False)

# %%
db="C:/Users/asus/Untitled Folder/movies.db"
conn=sqlite3.connect(db)
cur=conn.cursor()

# %% [markdown]
# 2.Get all the data about movies

# %%
#Establishing the connection with the DatBase 
cur.execute("select * from movies")
#creating curser object 
movies=cur.fetchall()
#crating the curser object 
movies
# Out:
# [('Avengers: Age of Ultron (2015)',
#   74,
#   86,
#   66,
#   7.1,
#   7.8,
#   5.0,
#   4.5,
#   3.7,
#   4.3,
#   3.3,
#   3.55,
#   3.9,
#   3.5,
#   4.5,
#   3.5,
#   3.5,
#   4.0,
#   1330,
#   271107,
#   14846,
#   0.5),
#  ('Cinderella (2015)',
#   85,
#   80,
#   67,
#   7.5,
#   7.1,
#   5.0,
#   4.5,
#   4.25,
#   4.0,
#   3.35,
#   3.75,
#   3.55,
#   4.5,
#   4.0,
#   3.5,
#   4.0,
#   3.5,
#   249,
#   65709,
#   12640,
#   0.5),
#  ('Ant-Man (2015)',
#   80,
#   90,
#   64,
#   8.1,
#   7.8,
#   5.0,
#   4.5,
#   4.0,
#   4.5,
#   3.2,
#   4.05,
#   3.9,
#   4.0,
#   4.5,
#   3.0,
#   4.0,
#   4.0,
#   627,
#   103660,
#   12055,
#   0.5),
#  ('Do You Believe? (2015)',
#   18,
#   84,
#   22,
#   4.7,
#   5.4,
#   5.0,
#   4.5,
#   0.9,
#   4.2,
#   1.1,
#   2.35,
#   2.7,
#   1.0,
#   4.0,
#   1.0,
#   2.5,
#   2.5,
#   31,
#   3136,
#   1793,
#   0.5),
#  ('Hot Tub Time Machine 2 (2015)',
#   14,
#   28,
#   29,
#   3.4,
#   5.1,
#   3.5,
#   3.0,
#   0.7,
# ...

# %%
#Establishing the connection with the DatBase 
curs.execute("select * from MoviesImdb")
#creating curser object 
Imdb_movies=curs.fetchall()
#Displaying the database content
Imdb_movies
# Out:
# [('https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'The Shawshank Redemption',
#   '1994',
#   'A',
#   '142 min',
#   'Drama',
#   9.3,
#   'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#   80.0,
#   'Frank Darabont',
#   'Tim Robbins',
#   'Morgan Freeman',
#   'Bob Gunton',
#   'William Sadler',
#   2343110,
#   '28,341,469'),
#  ('https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#   'The Godfather',
#   '1972',
#   'A',
#   '175 min',
#   'Crime, Drama',
#   9.2,
#   "An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son.",
#   100.0,
#   'Francis Ford Coppola',
#   'Marlon Brando',
#   'Al Pacino',
#   'James Caan',
#   'Diane Keaton',
#   1620367,
# ...

# %%
# Execute the query to get the table names
curs.execute("SELECT name FROM sqlite_master WHERE type='table'")

# Fetch all the table names as a list of tuples
tables = curs.fetchall()

# Print each table name
for table in tables:
    print(table[0])  # The table name is the first element in each tuple
# Out:
# movies
# Movies.db
# MoviesImdb

# %%
#creating the dataframe 
Movies=pd.DataFrame(Imdb_movies,columns=[
    'Poster_Link', 'Series_Title', 'Released_Year', 'Certificate', 
    'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 
    'Director', 'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'
])

# %%
df=pd.DataFrame(movies,columns = [
    'Title', 'Budget', 'Popularity', 'Meta', 'Meta_User', 'IMDB', 
    'F_Stars', 'F_Rating', 'RT_norm', 'RT_User_norm', 'IMDB_norm', 
    'RT_norm_rnd', 'RT_User_norm_rnd', 'Meta_norm_rnd', 'Meta_User_norm_rnd', 
    'IMDB_norm_rnd', 'Meta_User_Votes', 'IMDB_Votes', 'F_Votes', 'Revenue_Worldwide', 'Budget_Marketing', 'F_Diff'
]
)

# %%
df
# Out:
#                                          Title  Budget  Popularity  Meta  \
# 0               Avengers: Age of Ultron (2015)      74          86    66
# 1                            Cinderella (2015)      85          80    67
# 2                               Ant-Man (2015)      80          90    64
# 3                       Do You Believe? (2015)      18          84    22
# 4                Hot Tub Time Machine 2 (2015)      14          28    29
# ..                                         ...     ...         ...   ...
# 141                          Mr. Holmes (2015)      87          78    67
# 142                                 '71 (2015)      97          82    83
# 143                 Two Days, One Night (2014)      97          78    89
# 144  Gett: The Trial of Viviane Amsalem (2015)     100          81    90
# 145         Kumiko, The Treasure Hunter (2015)      87          63    68
#
#      Meta_User  IMDB  F_Stars  F_Rating  RT_norm  RT_User_norm  ...  \
# ...

# %%
# it tells 
df1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # it tells
# ----> 2 df1.info()
#
# NameError: name 'df1' is not defined

# %% [markdown]
# 3.Get all the data about director

# %%
#displaying the dataframe content
Movies
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
#Establishing the connection with the DatBase 
curs.execute("select Director,Star1,Star2,Star3,Star4,No_of_Votes,Gross from MoviesImdb")
#creating curser object 
directors=curs.fetchall()

# %%
directors
# Out:
# [('Frank Darabont',
#   'Tim Robbins',
#   'Morgan Freeman',
#   'Bob Gunton',
#   'William Sadler',
#   2343110,
#   '28,341,469'),
#  ('Francis Ford Coppola',
#   'Marlon Brando',
#   'Al Pacino',
#   'James Caan',
#   'Diane Keaton',
#   1620367,
#   '134,966,411'),
#  ('Christopher Nolan',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   2303232,
#   '534,858,444'),
#  ('Francis Ford Coppola',
#   'Al Pacino',
#   'Robert De Niro',
#   'Robert Duvall',
#   'Diane Keaton',
#   1129952,
#   '57,300,000'),
#  ('Sidney Lumet',
#   'Henry Fonda',
#   'Lee J. Cobb',
#   'Martin Balsam',
#   'John Fiedler',
#   689845,
#   '4,360,000'),
#  ('Peter Jackson',
#   'Elijah Wood',
#   'Viggo Mortensen',
#   'Ian McKellen',
#   'Orlando Bloom',
#   1642758,
#   '377,845,905'),
#  ('Quentin Tarantino',
#   'John Travolta',
#   'Uma Thurman',
#   'Samuel L. Jackson',
#   'Bruce Willis',
#   1826188,
#   '107,928,762'),
#  ('Steven Spielberg',
# ...

# %%
director=pd.DataFrame(directors,columns=["Director","Star1","Star2","Star3","Star4","No_of_Votes","Gross"])

# %%
director
# Out:
#                  Director              Star1              Star2  \
# 0          Frank Darabont        Tim Robbins     Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 2       Christopher Nolan     Christian Bale       Heath Ledger
# 3    Francis Ford Coppola          Al Pacino     Robert De Niro
# 4            Sidney Lumet        Henry Fonda        Lee J. Cobb
# ..                    ...                ...                ...
# 995         Blake Edwards     Audrey Hepburn     George Peppard
# 996        George Stevens   Elizabeth Taylor        Rock Hudson
# 997        Fred Zinnemann     Burt Lancaster   Montgomery Clift
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No_of_Votes        Gross
# 0        Bob Gunton  William Sadler      2343110   28,341,469
# 1        James Caan    Diane Keaton      1620367  134,966,411
# ...

# %% [markdown]
# # I create a Directors table from imdbmovies table

# %%
conn = sqlite3.connect('Movies.db')
director.to_sql('director', con=conn, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 conn = sqlite3.connect('Movies.db')
# ----> 2 director.to_sql('director', con=conn, if_exists='replace', index=False)
#
# NameError: name 'director' is not defined

# %%
db1="C:/Users/asus/Untitled Folder/directors.db"
# Connect to SQLite database
conn = sqlite3.connect(db1)
curs=conn.cursor()

# %%
#Establishing the connection with the DatBase 
curs.execute("select * from directors")
#creating curser object 
directors=curs.fetchall()
directors
# Out:
# [('Frank Darabont',
#   'Tim Robbins',
#   'Morgan Freeman',
#   'Bob Gunton',
#   'William Sadler',
#   2343110,
#   '28,341,469'),
#  ('Francis Ford Coppola',
#   'Marlon Brando',
#   'Al Pacino',
#   'James Caan',
#   'Diane Keaton',
#   1620367,
#   '134,966,411'),
#  ('Christopher Nolan',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   2303232,
#   '534,858,444'),
#  ('Francis Ford Coppola',
#   'Al Pacino',
#   'Robert De Niro',
#   'Robert Duvall',
#   'Diane Keaton',
#   1129952,
#   '57,300,000'),
#  ('Sidney Lumet',
#   'Henry Fonda',
#   'Lee J. Cobb',
#   'Martin Balsam',
#   'John Fiedler',
#   689845,
#   '4,360,000'),
#  ('Peter Jackson',
#   'Elijah Wood',
#   'Viggo Mortensen',
#   'Ian McKellen',
#   'Orlando Bloom',
#   1642758,
#   '377,845,905'),
#  ('Quentin Tarantino',
#   'John Travolta',
#   'Uma Thurman',
#   'Samuel L. Jackson',
#   'Bruce Willis',
#   1826188,
#   '107,928,762'),
#  ('Steven Spielberg',
# ...

# %% [markdown]
# 4.Check how many Movies are present in the ImDb  table

# %%
curs.execute("select Count(Series_Title) from MoviesImdb")
#creating curser object 
count=curs.fetchall()
print("The numbers of movies present in the iMDb dataset is",count[0])
# Out:
# The numbers of movies present in the iMDb dataset is (1000,)

# %% [markdown]
# 5.find thses 3 director :Blake Edwards,john woo,James Cameron

# %%
curs.execute("select Director,Series_Title,Released_Year  from MoviesImdb where Director in('Blake Edwards','John Woo','James Cameron')")
#creating curser object 
Particular_director=curs.fetchall()

# %%
Particular_director
# Out:
# [('James Cameron', 'Terminator 2: Judgment Day', '1991'),
#  ('James Cameron', 'Aliens', '1986'),
#  ('James Cameron', 'The Terminator', '1984'),
#  ('James Cameron', 'Avatar', '2009'),
#  ('James Cameron', 'Titanic', '1997'),
#  ('John Woo', 'Lat sau san taam', '1992'),
#  ('John Woo', 'Dip huet seung hung', '1989'),
#  ('Blake Edwards', "Breakfast at Tiffany's", '1961')]

# %% [markdown]
# 6. Find all the directors with name stating with Steven

# %%
curs.execute("SELECT Director,Series_Title,Released_Year  FROM MoviesImdb WHERE Director LIKE 'Steven%'")
Steven_director=curs.fetchall()
print(f"The directors whose names are starting with name 'Steven' are: {Steven_director}")
# Out:
# The directors whose names are starting with name 'Steven' are: [('Steven Spielberg', "Schindler's List", '1993'), ('Steven Spielberg', 'Saving Private Ryan', '1998'), ('Steven Spielberg', 'Raiders of the Lost Ark', '1981'), ('Steven Spielberg', 'Indiana Jones and the Last Crusade', '1989'), ('Steven Spielberg', 'Catch Me If You Can', '2002'), ('Steven Spielberg', 'Jurassic Park', '1993'), ('Steven Spielberg', 'Jaws', '1975'), ('Steven Spielberg', 'The Color Purple', '1985'), ('Steven Spielberg', 'E.T. the Extra-Terrestrial', '1982'), ('Steven Soderbergh', "Ocean's Eleven", '2001'), ('Steven Spielberg', 'Empire of the Sun', '1987'), ('Steven Spielberg', 'Bridge of Spies', '2015'), ('Steven Spielberg', 'Minority Report', '2002'), ('Steven Spielberg', 'Close Encounters of the Third Kind', '1977')]

# %% [markdown]
# 7.count the movies having cerficate A

# %%
curs.execute("SELECT count(Certificate)  FROM MoviesImdb WHERE Certificate=='A'")
certificateA=curs.fetchall()
print(f"The No. of Movies whose Certificate is 'A' are: {certificateA[0][0]}")
# Out:
# The No. of Movies whose Certificate is 'A' are: 197

# %% [markdown]
# 8.Find first 10th director from table

# %%
curs.execute("SELECT Director FROM MoviesImdb LIMIT 10")
firstten=curs.fetchall()
print(f"The First top ten director are: {firstten}")
# Out:
# The First top ten movies who have certificate A are: [('Frank Darabont',), ('Francis Ford Coppola',), ('Christopher Nolan',), ('Francis Ford Coppola',), ('Sidney Lumet',), ('Peter Jackson',), ('Quentin Tarantino',), ('Steven Spielberg',), ('Christopher Nolan',), ('David Fincher',)]

# %%
firstten
# Out:
# [('Frank Darabont',),
#  ('Francis Ford Coppola',),
#  ('Christopher Nolan',),
#  ('Francis Ford Coppola',),
#  ('Sidney Lumet',),
#  ('Peter Jackson',),
#  ('Quentin Tarantino',),
#  ('Steven Spielberg',),
#  ('Christopher Nolan',),
#  ('David Fincher',)]

# %% [markdown]
# 9. What are the 3 most popular movies ?

# %%
curs.execute("SELECT Series_Title FROM MoviesImdb WHERE IMDB_Rating>=9 LIMIT 3")
threemovies=curs.fetchall()
print(f"The Most popular three movies are: {threemovies}")
# Out:
# The Most popular three movies are: [('The Shawshank Redemption',), ('The Godfather',), ('The Dark Knight',)]

# %%
curs.execute("SELECT Series_Title,No_of_Votes FROM MoviesImdb ORDER BY No_of_Votes dESC LIMIT 3")
threemovies=curs.fetchall()
print(f"The Most popular three movies are: {threemovies[0][0]} , {threemovies[1][0]} and {threemovies[2][0]}")
# Out:
# The Most popular three movies are: The Shawshank Redemption , The Dark Knight and Inception

# %%
threemovies
# Out:
# [('The Shawshank Redemption', 2343110),
#  ('The Dark Knight', 2303232),
#  ('Inception', 2067042)]

# %% [markdown]
# 10. what are the 3 most bankable movies

# %%
curs.execute("SELECT Series_Title FROM MoviesImdb ORDER BY Gross dESC LIMIT 3")
threemovies=curs.fetchall()
print(f"The Most popular three movies are: {threemovies[0][0]} , {threemovies[1][0]} and {threemovies[2][0]}")
# Out:
# The Most popular three movies are: Rockstar , The Color Purple and Sherlock Jr.

# %%
threemovies
# Out:
# [('Rockstar',), ('The Color Purple',), ('Sherlock Jr.',)]

# %%
curs.execute("SELECT Series_Title,Gross FROM MoviesImdb ORDER BY Gross DESC LIMIT 3")
threemovies=curs.fetchall()
print(f"The Most popular three movies are: {threemovies[0][0]} , {threemovies[1][0]} and {threemovies[2][0]}")
# Out:
# The Most popular three movies are: Rockstar , The Color Purple and Sherlock Jr.

# %% [markdown]
# 11. what is most awarded average vote movie since the jan 1st ,2000

# %%
curs.execute("SELECT Series_Title,Released_Year,IMDB_Rating FROM MoviesImdb WHERE  Released_Year>=2000 ORDER BY IMDB_Rating dESC LIMIT 3")
mostawarded=curs.fetchall()
print(f"The Most awarded three movies are: {mostawarded[0][0]} , {mostawarded[1][0]} and {mostawarded[2][0]}")
# Out:
# The Most awarded three movies are: The Dark Knight , The Lord of the Rings: The Return of the King and Inception

# %%
mostawarded
# Out:
# [('The Dark Knight', '2008', 9.0),
#  ('The Lord of the Rings: The Return of the King', '2003', 8.9),
#  ('Inception', '2010', 8.8)]

# %% [markdown]
# 12.which movies were directed by Alfred Hitchcock?

# %%
curs.execute("SELECT MoviesImdb.Series_Title FROM MoviesImdb JOIN MoviesImdb on MoviesImdb.No_of_votes=MoviesImdb.No_of_Votes WHERE MoviesImdb.Director='Alfred Hitchcock'")
Directedmovies=curs.fetchall()
print(f"The movies which is directed by Alfred Hitchcock are: {Directedmovies}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 curs.execute("SELECT MoviesImdb.Series_Title FROM MoviesImdb JOIN MoviesImdb on MoviesImdb.No_of_votes=MoviesImdb.No_of_Votes WHERE MoviesImdb.Director='Alfred Hitchcock'")
#       2 Directedmovies=curs.fetchall()
#       3 print(f"The movies which is directed by Alfred Hitchcock are: {Directedmovies}")
#
# OperationalError: ambiguous column name: MoviesImdb.Series_Title

# %%
Directedmovies
# Out:
# [('Psycho',),
#  ('Rear Window',),
#  ('North by Northwest',),
#  ('Vertigo',),
#  ('Dial M for Murder',),
#  ('Rebecca',),
#  ('Rope',),
#  ('Strangers on a Train',),
#  ('Notorious',),
#  ('Shadow of a Doubt',),
#  ('The Lady Vanishes',),
#  ('The Birds',),
#  ('Lifeboat',),
#  ('The 39 Steps',)]

# %% [markdown]
# 13. Name the director  who has made the most movies

# %%
curs.execute("SELECT MoviesImdb.Series_Title FROM MoviesImdb JOIN MoviesImdb on MoviesImdb.No_of_votes=MoviesImdb.No_of_Votes group by Director_id order by count(name) DESC LIMIT 1")
Directedmovies=curs.fetchall()
print(f"The movies which is directed by Alfred Hitchcock are: {Directedmovies}")

# %%
Movies.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# 14. Name of the director who is most bankable

# %%
curs.execute("SELECT MoviesImdb.Director FROM MoviesImdb JOIN MoviesImdb on MoviesImdb.No_of_votes=MoviesImdb.No_of_Votes group by Director_id order by sum(budget) DESC LIMIT 1")
bankablemovies=curs.fetchall()
print(f"The movies which is most bankable are: {bankablemovies}")

# %% [markdown]
# # Budget Analysis

# %% [markdown]
# 1. tell the top 10 highest budget making movie

# %%
top_10=pd.DataFrame(curs.execute("SELECT * FROM MoviesImdb ORDER BY Gross DESC LIMIT 10"),columns=['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
       'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
       'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'])

# %%
top_10
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BOTc3Nz...
# 1  https://m.media-amazon.com/images/M/MV5BZDRkOW...
# 2  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 3  https://m.media-amazon.com/images/M/MV5BOGUyZD...
# 4  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 5  https://m.media-amazon.com/images/M/MV5BMjEzMz...
# 6  https://m.media-amazon.com/images/M/MV5BMTAxMD...
# 7  https://m.media-amazon.com/images/M/MV5BYzZhOD...
# 8  https://m.media-amazon.com/images/M/MV5BOGYwYW...
# 9  https://m.media-amazon.com/images/M/MV5BOTAzOD...
#
#                                  Series_Title Released_Year Certificate  \
# 0                                    Rockstar          2011          UA
# 1                            The Color Purple          1985           U
# 2                                Sherlock Jr.          1924      Passed
# 3                          The Social Network          2010          UA
# ...

# %% [markdown]
# No_of_Votes Analysis

# %% [markdown]
# 1. Find top 10 maximum No_of_Votes making movies

# %%
Top_revenue_movies=pd.DataFrame(curs.execute("SELECT * FROM MoviesImdb ORDER BY No_of_Votes dESC LIMIT 10"),columns=['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
       'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
       'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'])

# %%
Top_revenue_movies
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 3  https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 4  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 5  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 6  https://m.media-amazon.com/images/M/MV5BNzQzOT...
# 7  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 8  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 9  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                                         Series_Title Released_Year  \
# 0                           The Shawshank Redemption          1994
# 1                                    The Dark Knight          2008
# 2                                          Inception          2010
# 3                                         Fight Club          1999
# ...

# %% [markdown]
# # Rating analysis

# %% [markdown]
# Find the most popular movies with highest rating

# %%
Top_rating_movies=pd.DataFrame(curs.execute("SELECT * FROM MoviesImdb ORDER BY Imdb_Rating dESC LIMIT 10"),columns=['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
       'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
       'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'])

# %%
Top_rating_movies
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %% [markdown]
# # DIRECTOR ANALYSIS

# %% [markdown]
# 1. NAME ALL THE DIRECTORS WITH THE total numbers of movies and budget

# %%
Top_rating_directors=pd.DataFrame(curs.execute("SELECT Director,COUNT(*) as 'Total Movies',SUM(Gross) FROM MoviesImdb GROUP BY Director ORDER BY sum(Gross) dESC LIMIT 10"),columns=['Director','Total Movies',"Budget"
])

# %%
Top_rating_directors
# Out:
#             Director  Total Movies  Budget
# 0   Steven Spielberg            13  2474.0
# 1      Anthony Russo             4  2203.0
# 2  Christopher Nolan             8  1934.0
# 3        Satoshi Kon             3  1785.0
# 4      James Cameron             5  1746.0
# 5      Peter Jackson             5  1595.0
# 6         Tomm Moore             2  1543.0
# 7        J.J. Abrams             3  1421.0
# 8         Imtiaz Ali             2  1395.0
# 9          Brad Bird             4  1098.0

# %% [markdown]
# Name all the director with the number of movies and revenue where number of movies should be taken into account for doing the analysis.

# %%
directors_movies=pd.DataFrame(curs.execute("SELECT Director,COUNT(Series_Title)  FROM MoviesImdb GROUP BY Director ORDER BY COUNT(Series_Title) DESC LIMIT 10"),columns=['Director','Total Movies',
])

# %%
directors_movies
# Out:
#             Director  Total Movies
# 0   Alfred Hitchcock            14
# 1   Steven Spielberg            13
# 2     Hayao Miyazaki            11
# 3    Martin Scorsese            10
# 4     Akira Kurosawa            10
# 5        Woody Allen             9
# 6    Stanley Kubrick             9
# 7       Billy Wilder             9
# 8  Quentin Tarantino             8
# 9      David Fincher             8

# %% [markdown]
# 3.Give the title of the movies, release_date,Budget,revene,rating ,No_of_Votes made by Stevel spielberg

# %%
directors_movies=pd.DataFrame(curs.execute("SELECT Series_Title,Released_Year,Gross,Meta_Score,Imdb_Rating,No_of_Votes  FROM MoviesImdb where Director='Steven Spielberg'"),columns=['Series_Title','Released_Year','Gross','Meta_Score','Imdb_Rating','No_of_Votes'])

# %%
directors_movies
# Out:
#                           Series_Title Released_Year        Gross  Meta_Score  \
# 0                     Schindler's List          1993   96,898,818        94.0
# 1                  Saving Private Ryan          1998  216,540,909        91.0
# 2              Raiders of the Lost Ark          1981  248,159,971        85.0
# 3   Indiana Jones and the Last Crusade          1989  197,171,806        65.0
# 4                  Catch Me If You Can          2002  164,615,351        75.0
# 5                        Jurassic Park          1993  402,453,882        68.0
# 6                                 Jaws          1975  260,000,000        87.0
# 7                     The Color Purple          1985   98,467,863        78.0
# 8           E.T. the Extra-Terrestrial          1982  435,110,554        91.0
# 9                    Empire of the Sun          1987   22,238,696        62.0
# 10                     Bridge of Spies          2015   72,313,754        81.0
# ...
